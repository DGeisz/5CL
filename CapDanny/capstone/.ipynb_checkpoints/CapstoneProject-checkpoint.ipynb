# %% [markdown]
# # Capstone Project: Blackbody Radiation

# %% [markdown]
# # Objective
# * In this lab, we will explore the Blackbody Radiation Spectrum and Wien's Law
# * We will attempt to verify Wien's Law
#
# # Theory
#
# For our capstone project, we wish to test Planck’s Law for the Blackbody Radiation spectrum.  Planck's Law takes the form:
#
# $$B_\lambda (\lambda, T) = \frac{2hc^2}{\lambda ^5}\frac{1}{e _{}^{\frac{hc}{\lambda k_B T} - 1}}$$
#
# Here, $B_{\lambda}$ is the spectral radiance of a Blackbody, $\displaystyle h$, $c$, and $k_B$ are Planck's unreduced constant, the speed of light, and Boltzmann's Constant respectively, and $T$ and $\lambda$ are the temperature of Blackbody and the wavelength of light respectively.
#
#
# We also wish to verify Wien's Law.  Wien's Law states that the wavelength $\lambda_{max}$ at which the spectral radiance of a Blackbody is greatest is related to the Blackbody Temperature $T$ according to the relation:
#
# $$\lambda_{max} = \frac{b}{T}$$
# Where $b$ is Wien's Constant and theoretically takes the form:
#
# $$b = \frac{hc}{xk_B}$$
#
# where $x$ is the solution to the equation:
#
# $$\frac{xe^x}{e^x - 1} - 5 = 0$$
#
# which can be numerically solved to yield:
#
# $$x \approx 4.965114231744276$$
#
# In this lab, we will be using a tungsten bulb as our approximate black body.  In order to determine the temperature of the tungsten filament, we are going to use the temperature dependence of resistivity formula for metals, which takes the form:
#
# $$R_T = R_0 \left[1 + \alpha\left(T - T_0\right)\right]$$
#
# $$\implies T = \left(\dfrac{R}{R_{0}} - 1\right) \dfrac{1}{\alpha} + T_{0}$$
#
#
# Where $R_0$ is the resistance of the metal at temperature $T_0$, $R_T$ is the temperature of the metal at temperature $T$, and $\alpha$ is a constant that depends of the metal.  The final equation gives the error propagation formula. Using Ohm's law,
#
# $$R = \frac{V}{I}$$
#
# we will determine the resistance of the filament at room temperature.  To determine the temperature of the filament when we power the light bulb, we can use Ohm's law to determine the resistance of the filament, and then use the fact that $\alpha = 0.0045 \frac{Ohm}{^0C}$ for tungsten to determine the temperature of the filament.  Using $V_0 = I_0 R_0$ and $V = IR$, the corresponding formula for the error propagation of the above formula is given by:
#
# $$\delta T = \sqrt{\left(\dfrac{I_{0}\delta V}{I\alpha V_{0}}\right)^2 + \left(\dfrac{VI_{0}\delta I}{V_{0}\alpha I^{2}}\right)^{2} + \left(\dfrac{V\delta I_0}{IV_{0}\alpha}\right)^{2} + \left(\dfrac{VI_{0}\delta V_0}{I\alpha V_{0}^{2}}\right)^{2}}$$

# %% [markdown]
# # Equipment & Procedure
# ## Equipment List
# * Tungsten Bulb
# * Power Supply
# * Vernier Photodetector
# * Monochromator
# * Three Lasers with Known Wavelengths
# * Cardboard Box
# * Thermocouple
# * Current Clamp
# * Multimeter
#
#
# ## Procedure
# ### Monochromator Calibration
# 1. Shine the first of the three lasers through the opening to the monochromator.
# 2. Adjust the wavelength dial on the monochromator until the laser light is emitted from the device.
# 3. Record the monochromator's wavelength reading and the actual wavelength of the laser.
# 4. Repeat steps 1-3 with the other two lasers.
# 5. Use the data collected to determine the offset between the monochromator's wavelength reading and the wavelength of light actually being emitted from the device.
#
# ### Experimental Procedure
# 1. Set up materials according the diagram below.
# ![Apparatus](IMG-0012.JPG)
# 2. Turn on the Tungsten bulb to a low setting.
# 3. Take the lid off the monochromator, and align the bulb so that the light emitted into the monochromator is incident on both mirrors and the grating inside the monochromator. Do not adjust any of the optical devices within the monochromator.
# 4. Align the photodetector so that the light emitted from the monochromator is incident on the aperture of the detector.
# 5. The smallest reading from a vernier photodetector is 2.0 Lux, so adjust the wavelength dial on the monochromator until the photodetector reads a value just above 2.0 Lux.
# 6. By turning the wavelength dial on the monochromator, record the photodetector reading over the range of wavelengths for which the photodetector reads a value greater than 2.0 Lux.  In our case, we started at the smallest wavelength for which the photodetector read a value greater than 2.0 Lux, and we increased the wavelength by about 100 Angstrom between subsequent data points.
# 7. Repeat steps 5 and 6 four times, but each time change the power supplied to the Tungsten bulb to change its temperature.  Be sure to record the power setting each time you repeat the experiment.
# 8. Turn off the power supply, and connect the multimeter in parallel to the circuit, and clamp the current clamp onto one of the light bulb wires.
# 9. Turn on the power supply to the lowest setting at which current flows through the bulb.
# 10. Use the multimeter and the current clamp to find the voltage across the light bulb and the current running through the circuit.  Use these values to give an approximate value of the resistance of the bulb at room temperature.
# 11. Turn the power supply to each of the power settings used in steps 1-7, and at each setting, record the voltage across the light bulb and the current in the circuit. Use these values to determine the resistance of the light bulb at each power setting.  Used with equations in the theory section, these values can give you an approximate value for the temperature of the filament.

# %% [markdown]
# # Data
# ## Calibration Data
#
# The following data table represents the calibration data we took for the monochromator using three lasers with known wavelengths (see procedure for details).  Here "Wavelength Reading" represents the value of wavelength displayed by the monochromator, and "Actual Wavelength" represents the actual wavelength of the lasers.  "Wavelength Reading" technically has units of Angstroms, but because one of the lab instructors replaced the diffraction grating inside the monochromator, the monochromator's wavelength reading is about half as large as the actual wavelength.  We will take this into consideration when processing the data in our data analysis section.  "Actual Wavelength" also has units of Angstroms.

# %%
cal_data
# Out:
#    Wavelength Reading  Actual Wavelength
# 0                3816               6328
# 1                3332               5320
# 2                2727               4050

# %% [markdown]
# ## External Data
# The Photodetector does not sample different wavelengths uniformly because it attempts to mimic a human eye.  Because we are trying to find the spectral radiance of the Tungsten Bulb, we will need to divide our raw data by the Photodetector's Light Sensitivity at each wavelength.  The Following Graph shows the Photodetector's Sensitivity as a function of wavelength.  Here, "Sensitivity" refers the percentage of the light incident on the Photodetector that the detector is able to measure.  It is essentially a wavelength dependent transmission coefficient.  "Wavelength" refers to the wavelength of light, measured in nanometers.

# %%
wl = np.linspace(440, 710, 100)
plt.plot(wl, photo_sensitivity(wl))
plt.xlabel("Wavelength (nm)")
plt.ylabel("Sensitivity")
plt.title("Photodetector Sensitivity vs. Wavelength")
plt.show()

# %% [markdown]
# The monochromator also does not evenly transmit light at all wavelengths. The following graph shows the monochromator's efficiency as a function of wavelength.  Here, "Efficiency" refers to the percentage of the light incident on the monochromator that the monochromator transmits.  It is essentially a wavelength dependent transmission coefficient.  "Wavelength" refers to the wavelength of the light in nanometers.

# %%
wl = np.linspace(452, 730, 100)
plt.plot(wl, monochromator_sensitivity(wl))
plt.xlabel("Wavelength (nm)")
plt.ylabel("Efficiency")
plt.ylim(.4, .9)
plt.title("Monochromator Efficiency vs. Wavelength")
plt.show()

# %% [markdown]
# ## Spectral Data
# The following Data Tables represent the spectral data we took in this experiment.  This first data table represents the data we took on the second day when we were able to finally start taking data.  Here, "Wavelength Reading" refers to the wavelength displayed by the monochromator, and "Illuminance" refers to the photodetector reading.  "Wavelength Reading" is measured in Angstroms (see the Calibration Data section for more details), and "Illumiance" is measured in Lux.  This data was taken at a power setting of 100 on the power supply we used.

# %%
data_day2.iloc[0:30]
# Out:
#     Wavelength Reading  Illuminance
# 0               2750.0          2.6
# 1               2800.0          3.2
# 2               2850.0          3.9
# 3               2900.0          4.9
# 4               2950.0          5.9
# 5               3000.0          7.0
# 6               3050.0          8.3
# 7               3100.0          9.8
# 8               3150.0         11.2
# 9               3200.0         12.7
# 10              3250.0         14.7
# 11              3300.0         16.0
# 12              3350.0         17.7
# 13              3400.0         19.2
# 14              3450.0         20.5
# 15              3500.0         21.1
# 16              3550.0         21.1
# 17              3600.0         20.7
# 18              3650.0         19.8
# 19              3700.0         18.3
# 20              3750.0         16.5
# 21              3800.0         14.5
# 22              3850.0         12.4
# 23              3900.0         10.3
# 24              3950.0          8.3
# ...

# %% [markdown]
# This second data table represents the data we took on the third day.  I have split this data table from the above data table because we were unable to avoid changes in the exact positions of the Tungsten bulb and the photodetector relative to the monochromator each time we set up our experimental apparatus.  Because of this, we expect slight changes in the relative magnitude of our illuminance measurements between the two days.  Regardless of this change, the location of the peak of our spectral radiance curves should not depend on the exact geometry of our setup, so both sets of data will be useful in our data analysis.
#
# Here, "Wavelength Reading" refers once again to the wavelength displayed by the monochromator in Angstroms, and "Illuminance" refers to the photodetector reading in Lux.  The value in parenthesis after "Illuminance" refers to the power setting of the power supply for a given column of data.  Values of "NaN" occur when we were unable to take data at a particular wavelength and power setting because the photodetector bottomed out.

# %%
day3.iloc[0:32]
# Out:
#     Wavelength Reading  Illuminance (89)  Illuminance (110)  \
# 0               4149.0               2.4                2.6
# 1               4249.0               2.6                3.2
# 2               4349.0               3.1                3.9
# 3               4449.0               3.7                4.9
# 4               4549.0               4.5                5.9
# 5               4649.0               5.4                7.0
# 6               4749.0               6.4                8.3
# 7               4849.0               7.6                9.8
# 8               4949.0               8.7               11.2
# 9               5049.0              10.2               12.7
# 10              5149.0              11.5               14.7
# 11              5249.0              12.7               16.0
# 12              5349.0              13.9               17.7
# 13              5449.0              15.1               19.2
# 14              5549.0              16.3               20.5
# ...

# %% [markdown]
# ## Temperature Data
#
# The following data table represents the data we took to determine the temperature of the filament at each power setting we used.  Here "Power Setting" refers the power setting of the power supply (it didn't give units, but we only use this value in the report as a reference), "I" refers the current through the circuit in Amperes, "V" refers to the voltage measured in volts.  This table also includes the value of resistance "R" in ohms that we calculated based on the values of "I" and "V," and it includes our calculation of the temperature "T" in Celsius using the temperature dependence of resistivity, and it's corresponding uncertainty "delT" which comes from propagating error in the temperature dependence of resistivity equation.
# Once again the value of $\alpha$ for tungsten is $0.0045 \frac{Ohms}{^0C}$

# %%
temp
# Out:
#    Power Setting     I        V          R            T         delT
# 0             30  0.01    0.072   7.200000    25.400000     1.000000
# 1             89  0.80   55.300  69.125000  1936.665432  1825.713242
# 2            100  0.89   67.300  75.617978  2137.065973  1997.193647
# 3            110  0.97   77.500  79.896907  2269.131704  2110.199744
# 4            120  1.04   88.100  84.711538  2417.731434  2237.356109
# 5            140  1.16  107.700  92.844828  2668.758876  2452.160445

# %% [markdown]
# Also note that we took the temperature of the bulb to be room temperature when the power setting of the device was at 30, which is why T $\pm$ delT $ = 25.4 \pm 1$ $^0C$ at this setting.  Finally, the size of the uncertainty in our values for temperature are alarmingly large, but we triple-checked our math, and we determined that these values of uncertainty are so large because the temperature dependence of resistivity is a very inaccurate way to determine temperature, and therefore the corresponding equation for error propagation is prone to yield very large results.

# %% [markdown]
# # Data Analysis
# ## Determining Calibration Offset
# As mentioned in the Data section, one of our lab instructors replaced the diffraction grating in the monochromator with a grating that has a slit density twice as large as the original.  In addition to this, there was a natural calibration offset between the monochromator's wavelength reading and the actual wavelength it transmitted.  If we call this offset $\phi$, then we have the following equation:
#
# $$\text{Actual Wavelength} = 2 \cdot (\text{Wavelength Reading}) + \phi$$
#
# We therefore need to determine $\phi$ to further process our data.  Using our calibration data in the data section and the above equation, we determined the value of $\phi$ according to each calibration data point.  The following table shows each value of $\phi$ in Angstroms.

# %%
cal_data2 = pd.DataFrame()
cal_data2['phi'] = cal_data['Actual Wavelength'] - 2 * cal_data['Wavelength Reading']
cal_data2
# Out:
#     phi
# 0 -1304
# 1 -1344
# 2 -1404

# %% [markdown]
# We were instructed by one of our lab instructors to use the mean of these three values as our value for $\phi$, so we therefore have
# $$\phi = -1351 \;\text{Angstroms}$$

# %% [markdown]
# ## Processing Spectral Data
# Having found the calibration offset of the monochromator, we can now process and analyze the spectral data.  The first step in the process is using our calibration formula from the previous section to determine the actual wavelengths in our spectral data.  The following data tables represent the data from our Spectral Data tables in the Data section of this report, but with the corrected wavelengths.  Just as in the Spectral data section, the first data table represents the data we took on the second day, and the second data table represents the data we took on the third day.  Furthermore, "Wavelength" has units of Angstroms and "Illuminance" has units of Lux.

# %%
day2.iloc[0:30]
# Out:
#     Wavelength  Illuminance
# 0       4149.0          2.6
# 1       4249.0          3.2
# 2       4349.0          3.9
# 3       4449.0          4.9
# 4       4549.0          5.9
# 5       4649.0          7.0
# 6       4749.0          8.3
# 7       4849.0          9.8
# 8       4949.0         11.2
# 9       5049.0         12.7
# 10      5149.0         14.7
# 11      5249.0         16.0
# 12      5349.0         17.7
# 13      5449.0         19.2
# 14      5549.0         20.5
# 15      5649.0         21.1
# 16      5749.0         21.1
# 17      5849.0         20.7
# 18      5949.0         19.8
# 19      6049.0         18.3
# 20      6149.0         16.5
# 21      6249.0         14.5
# 22      6349.0         12.4
# 23      6449.0         10.3
# 24      6549.0          8.3
# 25      6649.0          6.5
# 26      6749.0          5.1
# 27      6849.0          4.0
# 28      6949.0          3.1
# 29      7049.0          2.3

# %%
dday3.iloc[0:32]
# Out:
#     Wavelength  Illuminance (89)  Illuminance (110)  Illuminance (120)  \
# 0       4149.0               2.4                2.6                6.2
# 1       4249.0               2.6                3.2                7.9
# 2       4349.0               3.1                3.9                9.7
# 3       4449.0               3.7                4.9               11.8
# 4       4549.0               4.5                5.9               14.3
# 5       4649.0               5.4                7.0               16.9
# 6       4749.0               6.4                8.3               20.5
# 7       4849.0               7.6                9.8               23.6
# 8       4949.0               8.7               11.2               27.8
# 9       5049.0              10.2               12.7               31.7
# 10      5149.0              11.5               14.7               35.8
# 11      5249.0              12.7               16.0               39.7
# ...

# %% [markdown]
# The following plot shows the Illuminance vs. Wavelength curve when the power setting was at 89.  I am including this plot because it shows the state of the data before we correct the spectral data using the photodetector's spectral sensitivity curve.

# %%
plt.plot(dday3.Wavelength, dday3['Illuminance (89)'], 'gx')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Illuminance (Lux)')
plt.title('Illuminance vs. Wavelength at Power Setting 89')
plt.show()

# %% [markdown]
# We can therefore see that this data is very similar in shape to the photodetector's spectral sensitivity curve, and therefore shows the necessity of correcting our data using the detector's sensitivity curve and the monochromator's efficiency curve in order to further analyze our data.
#
#
# The following data tables represent our spectral data after being corrected using the photodetector's sensitivity curve and the monochromator's efficiency curve.  To correct our data, we simply divided the raw data at a particular wavelength by the photodetector's spectral sensitivity and the monochromator's efficiency curve at that wavelength.  Because we have divided the Illuminance by the photodetector's luminosity function and the monochromator's efficiency curve, we are now measuring the radiant intensity at a given wavelength, but this quantity still technically has units of Lux.  Therefore I have replaced "Illuminance" in all the data tables with "RI" for radiant intensity.  Once again, I have split the data tables based on the day we collected the data.
#
# Also note that wavelengths beneath 4449 Angstroms and above 7149 Angstroms were left off because the photodetector's spectral sensitivity is only defined within these wavelengths.

# %%
dday2.iloc[0:27]
# Out:
#     Wavelength         RI
# 0       4449.0  39.796544
# 1       4549.0  43.061942
# 2       4649.0  45.328551
# 3       4749.0  48.917855
# 4       4849.0  52.776970
# 5       4949.0  55.548578
# 6       5049.0  57.936421
# 7       5149.0  61.971963
# 8       5249.0  62.139726
# 9       5349.0  62.656491
# 10      5449.0  62.839818
# 11      5549.0  61.919323
# 12      5649.0  61.300421
# 13      5749.0  60.483548
# 14      5849.0  61.392400
# 15      5949.0  63.379420
# 16      6049.0  65.088683
# 17      6149.0  65.282733
# 18      6249.0  63.625254
# 19      6349.0  60.636420
# 20      6449.0  57.042562
# 21      6549.0  52.365276
# 22      6649.0  47.527008
# 23      6749.0  43.870763
# 24      6849.0  42.143141
# 25      6949.0  42.396154
# 26      7049.0  42.015747

# %%
ddday3
# Out:
#     Wavelength    RI (89)   RI (110)    RI (120)    RI (140)
# 0       4449.0  30.050451  39.796544   95.836575  145.379211
# 1       4549.0  32.843854  43.061942  104.370469  156.190772
# 2       4649.0  34.967740  45.328551  109.436074  161.887683
# 3       4749.0  37.719792  48.917855  120.821208  176.811524
# 4       4849.0  40.929079  52.776970  127.095561  188.489180
# 5       4949.0  43.149342  55.548578  137.879506  199.875687
# 6       5049.0  46.531614  57.936421  144.612957  208.479878
# 7       5149.0  48.481468  61.971963  150.924917  210.788990
# 8       5249.0  49.323408  62.139726  154.184195  217.489041
# 9       5349.0  49.204815  62.656491  150.800368  207.439004
# 10      5449.0  49.420898  62.839818  151.208312  206.520443
# 11      5549.0  49.233413  61.919323  149.210467  203.276608
# 12      5649.0  49.388965  61.300421  149.619512  202.785280
# 13      5749.0  48.157517  60.483548  149.918938  197.216499
# ...

# %% [markdown]
# To better display this data, the following plots represent the data in the above tables.

# %%
plt.plot(dday2.Wavelength, dday2["RI"], 'x')
plt.title("Radiant Intensity vs. Wavelength (Day 2)")
plt.xlabel("Wavelength (Angstroms)")
plt.ylabel("Radiant Intensity (Lux)")
plt.show()

# %%
plt.plot(ddday3.Wavelength, ddday3['RI (89)'], 'x', label='89')
plt.plot(ddday3.Wavelength, ddday3['RI (110)'], 'x', label='110')
plt.plot(ddday3.Wavelength, ddday3['RI (120)'], 'x', label='120')
plt.plot(ddday3.Wavelength, ddday3['RI (140)'], 'x', label='140')
plt.title("Radiant Intensity vs. Wavelength (Day 3)")
plt.ylim(50, 400)
plt.xlabel("Wavelength (Angstroms)")
plt.ylabel("Radiant Intensity (Lux)")
plt.legend()
plt.show()

# %% [markdown]
# Referring to the our data for temperature, we see that the highest temperature calculated was about 2500 $^oC$.  The following figure shows blackbody spectra at different temperatures:
# ![Blackbody Spectra](tungstenlampsfigure1.jpg)

# %% [markdown]
# This table shows that our data does not at all resemble the blackbody spectrum at the temperatures we used.  We were working specifically in the visible wavelengths, and by inspecting the above figure, we see that the true blackbody spectrum is characterized by a monotonically increasing function in the visible wavelengths.  In our data, we see a variety of local maximums and minimums, which shows that our data does not agree with the predicted spectra.  There are a variety of reasons that our data did not match the theoretical prediction.  The first and perhaps most obvious is that Tungsten is not a perfect blackbody, and should therefore not be expected to yield a perfect blackbody spectrum.  Be that as it may, in other similar experiments that we researched on the internet, the spectral curve for tungsten was far more reminiscent of the theoretical blackbody curve than our data.  Another possible source of error is the fact that we only used three lasers to calibrate the monochromator.  Had we used more lasers, we would have been able to get more precise results for the constant offset between the raw and corrected wavelengths.  Finally, the data curves for the photodetector's sensitivity and the monochromator's efficiency did not come in data tables in their respective manuals, but rather in graphical forms, and so we had to do our best to transfer the data from those graphs to usable data tables, and in that process, we may have recorded incorrect values at some wavelengths for both the photodetector's spectral sensitivity and the monochromator's spectral efficiency.  To improve this experiment in the future, we could either find a photodetector and monochromator with better documentation regarding their respective spectral transmission coefficients, or we could take data on each device ourselves.  The latter option would be preferable to achieve the most accurate results, but the process would be very time consuming.
#
# The last piece of analysis that we can do is to determine if our data at all support Wien's law.  By inspecting the graphs that represent our processed data, we see that each graph is characterized by one maximum value in the visible wavelengths.  While this maximum value is not the maximum value predicted by the Planck's Equation for the blackbody spectrum, we want to see if the wavelength at which each of our graphs peaks is some constant fraction of the value of $\lambda_{max}$ predicted by Wien's Law.  If that were the case, if we let $\lambda_{dmax}$ be the value of wavelength at which our data reaches a maximum, then we would have $\lambda_{dmax} = \frac{c}{T}$, where $c$ is some constant scalar, and $T$ is the temperature of the filament.  In order to see if this is the case, we must find $\lambda_{dmax}$ for each of the values of $T$ at which we took data.  This is simply accomplished by inspecting the data tables that were included previously in this analysis.
#
# The following data table represents $\lambda_{dmax}$ for each of the values of $T$ at which we took data.  Here "Power Setting" refers to the power setting of the power supply at which we took data, "Temperature" and "delT" refer to the temperature and it's corresponding uncertainty for each power setting, with units of Celsius. "lambda_max" and "del_lambda" refer to the wavelength at which the Radiant intensity was greatest and that wavelength's corresponding uncertainty for each power setting.  The values of wavelength have units of Angstrom.

# %%
wien
# Out:
#    Power Setting  Temperature         delT  lambda_max  del_lambda
# 0             89  1936.665432  1825.713242        6249          25
# 1            100  2137.065973  1997.193647        6149          25
# 2            110  2269.131704  2110.199744        6149          25
# 3            120  2417.731434  2237.356109        6149          25
# 4            140  2668.758876  2452.160445        6049          25

# %% [markdown]
# Plotting $\frac{1}{T}$ versus $\lambda$, we see:

# %%
plt.plot(1 / wien.Temperature, wien.lambda_max, 'bo')
plt.title("1 / Temperature vs $\lambda$")
plt.xlabel("1 / Temperature (1 / Celsius)")
plt.ylabel("$\lambda$ ($\AA$)")
plt.show()

# %% [markdown]
# We therefore see that this data could potentially be modeled by a linear hypothesis.  If we fit the data to the hypothesis:
#
# $$\lambda_{dmax} = \hat{m}\left(\frac{1}{T}\right) + \hat{b}$$
#
# We would hope to find that $\hat{b} = 0$, which would show that $\lambda_{dmax}$ is in fact a constant multiple of $\lambda_{max}$, and would therefore somewhat validate Wien's Law.  Because uncertainty for our values of temperature are humongous, we will use a weighted least-squares fit for this data.  The script that calculates $\hat{m}$ and $\hat{b}$ is quite lengthy so I have included it in the references section.
#
# As can be seen in the references section, we have that
#
# $$\hat{m} = 1245757.3116098575 \pm 4742295.84971805\;^oC \cdot \unicode[serif]{xC5}$$
# $$\hat{b} = 5597.622005875043 \pm 2058.7735784622555\;\unicode[serif]{xC5}$$

# %% [markdown]
# A simple agreement test between our value of $\hat{b}$ and the expected value of 0 yields 1.359, so our experimentally determined value of $\hat{b}$ does agree with what we would expect from Wien's Law.  This indicates that the maxima we see in our data is not related to Wien's law, but rather probably has to do with an errors in our data for the photodetector's spectral sensitivity or the monochromator's spectral efficiency.
#
# At this point we have seen that our data does not resemble the theoretical prediction of Planck's law, and we have also seen that our data also does not support Wien's Law.  Perhaps the only piece of theoretical physics that our data even slightly supports is the Stefan-Boltzmann Law, which states that the radiant emittance $j$ of a blackbody is related to temperature according to the relation:
#
# $$j = \sigma T^4$$
#
# Where $\sigma$ is Stefan-Boltzmann constant.  While the nature of our experimental apparatus is such that we don't have the right data to properly compute $j$, we generally expect that as we increase temperature, spectral radiant intensity should increase over all wavelengths.  If we take another look at our data below,

# %%
plt.plot(ddday3.Wavelength, ddday3['RI (89)'], 'x', label='89')
plt.plot(ddday3.Wavelength, ddday3['RI (110)'], 'x', label='110')
plt.plot(ddday3.Wavelength, ddday3['RI (120)'], 'x', label='120')
plt.plot(ddday3.Wavelength, ddday3['RI (140)'], 'x', label='140')
plt.title("Radiant Intensity vs. Wavelength (Day 3)")
plt.ylim(50, 400)
plt.xlabel("Wavelength (Angstroms)")
plt.ylabel("Radiant Intensity (Lux)")
plt.legend()
plt.show()

# %% [markdown]
# We see that at higher power settings (which correspond to higher temperatures) we see higher values of radiant intensity, which slightly supports the Stefan-Boltzmann Law.  Unfortunately we do not have the data necessary to make any more substantial claims.

# %% [markdown]
# # Conclusions

# %% [markdown]
# Our objectives for this lab were to explore Blackbody radiation and Wien's Law, and to try to verify Wiens' Law.  While we were able to explore these topics, we were unsuccessful in quantitatively verifying either Wien's Law or Planck's Law for Blackbody radiation.
#
# As can be seen in the Data Analysis portion of this report, after we processed and corrected our data, our spectral Blackbody curves were all characterized by one maximum value in the the middle of the visible wavelengths, and a hump-like shape throughout.  Planck's Law predicted that a proper blackbody curve should be monotonically increasing with a negative second derivative, which is therefore quite different than our processed data.  While our experimentally determined blackbody curves on average displayed a negative second derivative and a positive first derivative, they were not representative of the theoretical prediction.  As discussed in the Data Analysis section, there are several possible explanations for this.  The first and perhaps most obvious is that Tungsten is not a perfect blackbody, and should therefore not be expected to yield a perfect blackbody spectrum.  Be that as it may, in other similar experiments that we researched on the internet, the spectral curve for tungsten was far more reminiscent of the theoretical blackbody curve than our data.  Another possible source of error is the fact that we only used three lasers to calibrate the monochromator.  Had we used more lasers, we would have been able to get more precise results for the constant offset between the raw and corrected wavelengths.  Finally, the data for the photodetector's sensitivity and the monochromator's efficiency did not come in data tables in their respective manuals, but rather in graphical forms, so we had to do our best to transfer the data from those graphs to usable data tables, and in the process we may have recorded incorrect values at some wavelengths for both the photodetector's spectral sensitivity and the monochromator's spectral efficiency.  To improve this experiment in the future, we could either find a photodetector and monochromator with better documentation regarding their respective spectral transmission coefficients, or we could take data on each device ourselves.  The latter option would be preferable to achieve the most accurate results, but the process would be very time consuming.
#
# Our most concrete objective for this experiment was to experimentally verify Wien's Law.  After we found the temperature of the bulb, we realized that the value of $\lambda_{max}$ for blackbody curves was predicted to be outside the visible wavelengths, so directly verifying Wien's Law would be impossible.  However, after inspecting our processed blackbody curves, I realized that each curve was characterized by one maximum value.  I hypothesized that perhaps the wavelength at which this value occurred was not a remnant of some error in the photodetector's spectral sensitivity or the monochromator's spectral efficiency, but rather was a constant multiple of the theoretical predicted value of $\lambda_{max}$.  If this were the case, then this wavelength would behave according to Wien's Law, but with a different constant than Wien's Constant.  As can be seen in the Data Analysis portion of this report, a weighted-least squares fit on a linear hypothesis showed that the wavelengths in question were not simply a constant multiple of the values of $\lambda_{max}$ predicted by Wien's Law, but were most likely a remnant of some error in the photodetector's spectral sensitivity or the monochromator's spectral efficiency.  Our data therefore did not experimentally verify Wien's Law.  In the future, if we wanted to verify Wien's Law, we would have to use a blackbody at a temperature above 4000 $^oC$ in order to for $\lamba_{max}$ to be in the visible wavelengths.  As will be discussed in the next paragraph, our method for determining temperature was not very accurate, and so to better verify Wien's Law, we would also need to use a better method for determining the temperature of the blackbody.
#
# As indicated in the last paragraph, using the temperature dependence of resistivity is not a very accurate way to determine the temperature of a metal.  The temperature dependence of resistivity is essentially a first order approximation, which means it is quite inaccurate.  As can be seen in our temperature data table, this method for determining temperature also produces incredibly large values of uncertainty after error propagation, which means it is highly untrustworthy.  In the future, to better determine the temperature of the Tungsten Bulb, we could use an Optical Pyrometer or some other device that yields more accurate and precise values for temperature when measuring hot metals.
#
# In conclusion, our experimental apparatus and procedure was not sufficient to verify Wien's Law or make any more substantial claims about the validity of Planck's Law.  In order to improve our experiment, we would either need to spend time gathering better data for the photodetector and monochromator's spectral transmission coefficients, or we would simply need to use more precise devices.  We would also need to find a way to heat our blackbody above 4000 $^oC$ and measure the temperature of the blackbody.

# %% [markdown]
# # References
#
#
# We took the picture of the Blackbody spectrum used in the Data Analysis section from the link below.

# %% [markdown]
# http://zeiss-campus.magnet.fsu.edu/articles/lightsources/tungstenhalogen.html

# %% [markdown]
# We used Python and the open source python libraries Pandas, Numpy, Matplotlib, and SciPy in this report.  The scripts included below were used to create data tables and process data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from IPython.display import Image
Im = Image('IMG-0012.JPG')
Im2 = Image('tungstenlampsfigure1.jpg')

# %% [markdown]
# The following script creates a numpy interpolation object (basically a function) that represents the radiant sensitivity of the Photodetector.

# %%
p_photo = pd.DataFrame()
photo_data = pd.read_csv('vernierData.csv')
Lslope = 600 / (980 - 328)
p_photo['lambda'] = Lslope * (photo_data.Lpix - 328) + 200
Sslope = 0.4 / (886 - 499)
p_photo['rad_sens'] = Sslope * (886 - photo_data.spix)
photo_sensitivity = interp1d(p_photo['lambda'], p_photo.rad_sens)

# %% [markdown]
# The following scripts creates a numpy interpolation object (basically a function) that represents the spectral efficiency of the monochromator.

# %%
m_sens = pd.DataFrame()
m_data = pd.read_csv('monochromator.csv')
m_sens['lambda'] = (500 / (982 - 272)) * (m_data.wlPix - 272) + 300
m_sens['eff'] = (1 / (526 - 244)) * (526 - m_data.effPix)
monochromator_sensitivity = interp1d(m_sens['lambda'], m_sens.eff)

# %% [markdown]
# The following script creates the raw spectral data tables displayed in the Data section.

# %%
data = pd.read_csv('readingvsintensity.csv')
data.keys()
data2 = pd.DataFrame(data)
data2
data_day2 = pd.DataFrame()
data_day2['Wavelength Reading'] = data['R(ans)\Power']
data_day2['Illuminance'] = data['100']
day3 = pd.DataFrame()
day3['Wavelength Reading'] = data['R(ans)\Power']
day3["Illuminance (89)"] = data['89']
day3["Illuminance (110)"] = data['100']
day3["Illuminance (120)"] = data['120']
day3["Illuminance (140)"] = data['140']

# %% [markdown]
# The following code is used to create the calibration data table in the Data section of the report.

# %%
cal_data = pd.DataFrame({"Wavelength Reading": [3816, 3332, 2727],
                        "Actual Wavelength": [6328, 5320, 4050]})

# %% [markdown]
# The following script produces spectral data tables with wavelengths corrected by the calibration equation.

# %%
day2 = pd.DataFrame()
day2['Wavelength'] = 2 * data_day2['Wavelength Reading'] - 1351
day2['Illuminance'] = data_day2.Illuminance
dday3 = pd.DataFrame.copy(day3)
dday3['Wavelength Reading'] = 2 * day3['Wavelength Reading'] - 1351
dday3.rename(columns={'Wavelength Reading': 'Wavelength'}, inplace=True)

# %% [markdown]
# The following scripts creates the data tables for the corrected spectral data.

# %%
ill_cols = dday3.columns.tolist()[1:]
dta = {}
wavel = []
for col in ill_cols:
    dta[col] = []
for index, row in dday3.iloc[4: 31].iterrows():
    wl = row.Wavelength
    wavel.append(wl)
    for col in ill_cols:
        dta[col].append(row[col] / (photo_sensitivity(wl / 10) * monochromator_sensitivity(wl / 10)))
new_data = {"Wavelength" : wavel}
for col in ill_cols:
    new_data["RI " + col.split()[1]] = dta[col]
print(photo_sensitivity(474.9))
ddday3 = pd.DataFrame(new_data)
ddday3

ill_cols = day2.columns.tolist()[1:]
dta = {}
wavel = []
for col in ill_cols:
    dta[col] = []
for index, row in day2.iloc[4: 31].iterrows():
    wl = row.Wavelength
    wavel.append(wl)
    for col in ill_cols:
        dta[col].append(row[col] / (photo_sensitivity(wl / 10) * monochromator_sensitivity(wl / 10)))
new_data = {"Wavelength" : wavel}
for col in ill_cols:
    new_data["RI"] = dta[col]
print(photo_sensitivity(474.9))
dday2 = pd.DataFrame(new_data)
# Out:
# 0.16967219829648766
# 0.16967219829648766

# %% [markdown]
# The following script creates the temperature data table displayed in the Data section of this report.

# %%
temp = pd.read_csv('../../CapHeidi/temp.csv')

# %%
temp['Power Setting'] = [30, 89, 100, 110, 120, 140]

# %%
temp.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
cols = temp.columns.tolist()
cols = cols[-1:] + cols[:-1]

# %%
temp = temp[cols]

# %%
temp.loc[0, 'delT'] = 1

# %%
wien = pd.DataFrame({'Power Setting': [89, 100, 110, 120, 140]})
wien['Temperature'] = temp.iloc[1: 6]['T'].tolist()
wien['delT'] = temp.iloc[1: 6]['delT'].tolist()
wien['lambda_max'] = [6249, 6149, 6149, 6149, 6049]
wien['del_lambda'] = [25 for _ in range(5)]

# %% [markdown]
# The following script uses a weighted least squares fit to calculate the values of $\hat{m}$ and $\hat{b}$ for our temperature and $\lambda_{dmax}$ data.

# %%
it = 1 / wien.Temperature
dit = wien.delT * (it **2)
l = wien.lambda_max
dl = wien.del_lambda
ms = ((it * l).mean() - (it.mean() * l.mean())) / ((it ** 2).mean() - (it.mean())**2)
bs = l.mean() - ms * it.mean()
w = 1 / ((dl **2) + ((ms * dit)**2))
denom = (w.sum() * (w * it * it).sum()) - ((w * it).sum()) **2
m_hat = (w.sum() * (w * it * l).sum() - (w * it).sum()*(w* l).sum()) / denom
b_hat = ((w * l).sum() - (w * m * it).sum()) / (w.sum())
dm_hat = (w.sum() / denom) ** .5
db_hat = ((w * it * it).sum() / denom)**0.5
print("m +- dm: ", m_hat, ' +- ', dm_hat)
print("b +- db: ", b_hat,' +- ', db_hat)
# Out:
# m +- dm:  1245757.3116098575  +-  4742295.84971805
# b +- db:  5597.622005875043  +-  2058.7735784622555
